# %%
import sys
print(sys.executable)          # should be …/envs/nlp_env/bin/python
import numpy as np, scipy as sp
print(np.__version__, sp.__version__)
# Out:
# /Users/farhananoor/anaconda3/envs/nlp_env/bin/python
# 1.26.4 1.15.2

# %%
import nltk
print("NLTK OK, version", nltk.__version__)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import nltk
#       2 print("NLTK OK, version", nltk.__version__)
#
# File ~/anaconda3/envs/nlp_env/lib/python3.11/site-packages/nltk/__init__.py:133
#     125     subprocess.Popen = _fake_Popen
#     127 ###########################################################
#     128 # TOP-LEVEL MODULES
#     129 ###########################################################
#     130
#     131 # Import top-level functionality into top-level namespace
# --> 133 from nltk.collocations import *
#     134 from nltk.decorators import decorator, memoize
#     135 from nltk.featstruct import *
#
# File ~/anaconda3/envs/nlp_env/lib/python3.11/site-packages/nltk/collocations.py:36
#      33 import itertools as _itertools
#      35 # these two unused imports are referenced in collocations.doctest
# ...
